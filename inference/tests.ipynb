# %%
import numpy as np

# %%
test = np.load('/pscratch/sd/e/epaillas/emc/v1.1/abacus/training_sets/cosmo+hod/dsc_pk.npy', allow_pickle=True).item()

# %%
test
# Out:
# {'k': array([0.01884956, 0.03141593, 0.0439823 , 0.05654867, 0.06911504,
#         0.08168141, 0.09424778, 0.10681415, 0.11938052, 0.13194689,
#         0.14451326, 0.15707963, 0.169646  , 0.18221237, 0.19477874,
#         0.20734512, 0.21991149, 0.23247786, 0.24504423, 0.2576106 ,
#         0.27017697, 0.28274334, 0.29530971, 0.30787608, 0.32044245,
#         0.33300882, 0.34557519, 0.35814156, 0.37070793, 0.3832743 ,
#         0.39584067, 0.40840704, 0.42097342, 0.43353979, 0.44610616,
#         0.45867253, 0.4712389 , 0.48380527, 0.49637164]),
#  'lhc_x': array([[ 0.02237 ,  0.12    ,  0.807952, ..., -0.2957  ,  0.09119 ,
#          -0.52551 ],
#         [ 0.02237 ,  0.12    ,  0.807952, ..., -0.67385 , -0.54968 ,
#          -0.40783 ],
#         [ 0.02237 ,  0.12    ,  0.807952, ...,  0.12739 ,  0.18381 ,
#           0.02242 ],
#         ...,
#         [ 0.02169 ,  0.1112  ,  0.730036, ...,  0.64002 , -0.26866 ,
#          -0.63894 ],
# ...
